# %% [markdown]
# <a href="https://colab.research.google.com/github/GeerbaniShashi/Open_Source_Models_with_Hugging_Face/blob/main/VQA_using_BLIP_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install transformers

# %%
from transformers.utils import logging
logging.set_verbosity_error()
import warnings
warnings.filterwarnings("ignore", message = "Using the model-agnostic default 'max-length")

# %%
from transformers import BlipForQuestionAnswering

# %%
model = BlipForQuestionAnswering.from_pretrained("Salesforce/blip-vqa-base")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.54G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/788 [00:00<?, ?it/s]

# %%
from transformers import AutoProcessor

# %%
processor = AutoProcessor.from_pretrained("Salesforce/blip-vqa-base")
# Out:
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
from PIL import Image

# %%
image = Image.open("/content/WIN_20260309_20_20_08_Pro.jpg")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720>

# %%
question = "What is her name?"

# %%
inputs = processor(image, question, return_tensors = "pt")

# %%
out = model.generate(**inputs)
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py:1616: UserWarning: Using the model-agnostic default `max_length` (=21) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
print(processor.decode(out[0], skip_special_tokens = True))
# Out:
# unknown
